# %%
import pydicom
import matplotlib.pyplot as plt

# %%
# import torch
# torch.cuda.is_available()

# %%
dicom_file = "../data/raw/train_images/4003253/702807833/1.dcm"
dicom_data = pydicom.dcmread(dicom_file)

# %%
# Crear función para abrir las fotos

def open_image():
    dicom_photo = "../data/raw/train_images/4003253/702807833/i.dcm"

# %%
image = dicom_data.pixel_array

# %%
plt.imshow(image, cmap=plt.cm.bone)
plt.show()

# %%
print(f"rows: {dicom_data.Rows}\ncolumnas: {dicom_data.Columns}")
# Out:
# rows: 640
# columnas: 640
